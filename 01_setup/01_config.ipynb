# %%
# Databricks notebook source
storage_account = "rcmhealthcare123"
container = "bronze"

# Root of your container
base_path = f"abfss://{container}@{storage_account}.dfs.core.windows.net"

# In your case, bronze_path is the container root
bronze_path = base_path

# Put checkpoints/schemas INSIDE the same container (recommended)
checkpoint_path = f"{base_path}/_checkpoints"
schema_path     = f"{base_path}/_schemas"

# %%
# %sql
create schema if not exists stg_bronze;

create schema if not exists silver;
create schema if not exists stg_silver;

create schema if not exists gold;
