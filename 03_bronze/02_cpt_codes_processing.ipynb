# %%
# %run "../01_setup/01_config"

# %%
df = spark.read.format('csv')\
    .option('header', True)\
        .load(f"{landing_path}/cpt_codes")

# %%
from pyspark.sql import functions as F

df = df.withColumn('ingested_date', F.lit(F.current_timestamp()))

# %%
df.write.mode('overwrite').format('parquet').save(f"{bronze_path}/cpt_codes")
